# %% [markdown]
# ### Московский Авиационый Институт
#  #### (НАЦИОНАЛЬНЫЙ ИССЛЕДОВАТЕЛЬСКИЙ УНИВЕРСИТЕТ)
#  #### Лабороторная работа №7
#  #### По дисциплине "Программирование на Python"
#  #### На тему "Работа с библиотекой Pandas"
#  #### Выполнил студент группы Т12о-101М: Трусова В.Л.
#  #### Работу принял: Поповкин А.В.
#  ##### Дата: 5.12.2020
#  ##### Москва, 2020г.

# %%
import sys
import pandas as pd
import numpy as np
import random
import matplotlib.pyplot as plt

# %% [markdown]
# #### 1. Прочитать файл CSV и перевести его в DataFrame

# %%
url = 'https://raw.githubusercontent.com/Grossmend/CSV/master/titanic/data.csv'

# %%
pd.read_csv(url)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# #### 2. Прочитать файл CSV (определенные столбцы и определенное кол-во строк) 'Name', 'Sex', 'Survived' и перевести его в DataFrame

# %%
pd.read_csv(url, nrows=5, usecols=['Name', 'Sex', 'Survived'])
# Out:
#    Survived                                               Name     Sex
# 0         0                            Braund, Mr. Owen Harris    male
# 1         1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2         1                             Heikkinen, Miss. Laina  female
# 3         1       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4         0                           Allen, Mr. William Henry    male

# %% [markdown]
# #### 3. Прочитать файл CSV и перевести каждую 100-ую строку в DataFrame

# %%
df = pd.read_csv(url, chunksize=100)
df_p = pd.DataFrame()

for chunk in df:
    df_p = df_p.append(chunk.iloc[0])
    
df_p.head()
# Out:
#       Age Cabin Embarked    Fare                                      Name  \
# 0    22.0   NaN        S  7.2500                   Braund, Mr. Owen Harris
# 100  28.0   NaN        S  7.8958                   Petranec, Miss. Matilda
# 200  28.0   NaN        S  9.5000            Vande Walle, Mr. Nestor Cyriel
# 300   NaN   NaN        Q  7.7500  Kelly, Miss. Anna Katherine "Annie Kate"
# 400  39.0   NaN        S  7.9250                        Niskanen, Mr. Juha
#
#      Parch  PassengerId  Pclass     Sex  SibSp  Survived             Ticket
# 0      0.0          1.0     3.0    male    1.0       0.0          A/5 21171
# 100    0.0        101.0     3.0  female    0.0       0.0             349245
# 200    0.0        201.0     3.0    male    0.0       0.0             345770
# 300    0.0        301.0     3.0  female    0.0       1.0               9234
# 400    0.0        401.0     3.0    male    0.0       1.0  STON/O 2. 3101289

# %% [markdown]
# #### 4. Преобразовать индексы объекта Series в столбец DataFrame

# %%
s = pd.Series(list('pandas&numpy'))
df = s.to_frame().reset_index()
df.columns=['number', 'letter']
df
# Out:
#     number letter
# 0        0      p
# 1        1      a
# 2        2      n
# 3        3      d
# 4        4      a
# 5        5      s
# 6        6      &
# 7        7      n
# 8        8      u
# 9        9      m
# 10      10      p
# 11      11      y

# %% [markdown]
# #### 5. Посмотреть информацию объекта DataFrame

# %% [markdown]
#     5.1 Вывести формат каждого столбца

# %%
df = pd.read_csv(url)
print('Формат столбцов:')
print(df.dtypes)
# Out:
# Формат столбцов:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
#     5.2 Вывести размерность DataFrame

# %%
print('Размерность:')
print(df.shape)
# Out:
# Размерность:
# (891, 12)

# %% [markdown]
#     5.3 Вывести общую статистику

# %%
print('Общая статистика:')
print(df.describe())
# Out:
# Общая статистика:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200
